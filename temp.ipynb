# %%
import tifffile as tiff

import matplotlib.pyplot as plt

# 文件路径
file_path = "/media/hdd/sonwe1e/DeepLearningTemplate/dataset/train/2_Opt/0001_Train.tif"

# 读取 TIFF 图像
img = tiff.imread(file_path)

# 可视化
plt.figure(figsize=(6, 6))
plt.imshow(img, cmap='gray')
plt.title('0001_Train.tif')
plt.axis('off')
plt.show()

# %%
img.max(), img.min(), img.shape, img.dtype, img.mean(), img.std()
# Out:
# (np.uint8(255),
#  np.uint8(24),
#  (512, 512, 3),
#  dtype('uint8'),
#  np.float64(103.46127065022786),
#  np.float64(27.9701517589987))
